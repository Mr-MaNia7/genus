# %% [markdown]
# #**Preprocessing Data**

# %%
header = 'filename chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'
for i in range(1, 21):
    header += f' mfcc{i}'
header += ' label'
header = header.split()
print(header)
# Out:
# ['filename', 'chroma_stft', 'rmse', 'spectral_centroid', 'spectral_bandwidth', 'rolloff', 'zero_crossing_rate', 'mfcc1', 'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5', 'mfcc6', 'mfcc7', 'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12', 'mfcc13', 'mfcc14', 'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19', 'mfcc20', 'label']

# %%
import csv
import os
import librosa
import numpy as np
file = open('final_dataset.csv', 'w', newline='')
with file:
    writer = csv.writer(file)
    writer.writerow(header)
genres = 'blues country hiphop'.split()
for g in genres:
    for filename in os.listdir(f'/content/drive/MyDrive/music_dataset/{g}'):
        songname = f'/content/drive/MyDrive/music_dataset/{g}/{filename}'
        y, sr = librosa.load(songname, mono=True, duration=30)
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        rmse = librosa.feature.rms(y=y)
        spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
        for e in mfcc:
            to_append += f' {np.mean(e)}'
        to_append += f' {g}'
        file = open('final_dataset.csv', 'a', newline='')
        with file:
            writer = csv.writer(file)
            writer.writerow(to_append.split())
print("Done")
# Out:
# Done

# %%
import pandas as pd
data = pd.read_csv('data_final.csv')
data.head()
# Out:
#           filename  chroma_stft      rmse  spectral_centroid  \
# 0  blues.00004.wav     0.308590  0.091563        1835.494603
# 1  blues.00001.wav     0.340983  0.095918        1529.835316
# 2  blues.00002.wav     0.363603  0.175573        1552.481958
# 3  blues.00003.wav     0.404779  0.141191        1070.119953
# 4  blues.00006.wav     0.291308  0.141796        1459.078483
#
#    spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0         1748.362448  3580.945013            0.101500 -160.266037
# 1         2038.617579  3548.820207            0.056044 -207.556793
# 2         1747.165985  3040.514948            0.076301  -90.754387
# 3         1596.333948  2185.028454            0.033309 -199.431152
# 4         1388.913312  2795.616429            0.073028 -190.149460
#
#         mfcc2      mfcc3  ...    mfcc12    mfcc13    mfcc14    mfcc15  \
# 0  126.198799 -35.605450  ... -2.806384 -6.934123 -7.558618 -9.173553
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   filename            78 non-null     object
#  1   chroma_stft         78 non-null     float64
#  2   rmse                78 non-null     float64
#  3   spectral_centroid   78 non-null     float64
#  4   spectral_bandwidth  78 non-null     float64
#  5   rolloff             78 non-null     float64
#  6   zero_crossing_rate  78 non-null     float64
#  7   mfcc1               78 non-null     float64
#  8   mfcc2               78 non-null     float64
#  9   mfcc3               78 non-null     float64
#  10  mfcc4               78 non-null     float64
#  11  mfcc5               78 non-null     float64
#  12  mfcc6               78 non-null     float64
#  13  mfcc7               78 non-null     float64
#  14  mfcc8               78 non-null     float64
# ...

# %%
data.shape
# Out:
# (78, 28)

# %%
data.dtypes
# Out:
# filename               object
# chroma_stft           float64
# rmse                  float64
# spectral_centroid     float64
# spectral_bandwidth    float64
# rolloff               float64
# zero_crossing_rate    float64
# mfcc1                 float64
# mfcc2                 float64
# mfcc3                 float64
# mfcc4                 float64
# mfcc5                 float64
# mfcc6                 float64
# mfcc7                 float64
# mfcc8                 float64
# mfcc9                 float64
# mfcc10                float64
# mfcc11                float64
# mfcc12                float64
# mfcc13                float64
# mfcc14                float64
# mfcc15                float64
# mfcc16                float64
# mfcc17                float64
# mfcc18                float64
# mfcc19                float64
# mfcc20                float64
# label                  object
# dtype: object

# %%
data = data.drop(labels='filename',axis=1)

# %%
data
# Out:
#     chroma_stft      rmse  spectral_centroid  spectral_bandwidth      rolloff  \
# 0      0.308590  0.091563        1835.494603         1748.362448  3580.945013
# 1      0.340983  0.095918        1529.835316         2038.617579  3548.820207
# 2      0.363603  0.175573        1552.481958         1747.165985  3040.514948
# 3      0.404779  0.141191        1070.119953         1596.333948  2185.028454
# 4      0.291308  0.141796        1459.078483         1388.913312  2795.616429
# ..          ...       ...                ...                 ...          ...
# 73     0.461870  0.165603        2677.530256         2337.258126  5366.425883
# 74     0.381839  0.190620        2240.286593         2193.804234  4728.029744
# 75     0.439649  0.173611        2025.641660         2272.819110  4603.638829
# 76     0.507344  0.251695        2305.338720         2227.384244  4815.670880
# 77     0.430908  0.178736        2517.911424         2163.918800  4926.570210
#
# ...
